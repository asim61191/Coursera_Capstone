# %%
import pandas as pd

#Read data html table into data frames
dfs = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

#Get the first table from the list of tables
df = dfs[0]
df
# Out:
#     Postcode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 9        M8A      Not assigned
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 13       M2B      Not assigned
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 20       M7B      Not assigned
# 21       M8B      Not assigned
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# ..       ...               ...
# 258      M9X      Not assigned
# 259      M1Y      Not assigned
# 260      M2Y      Not assigned
# 261      M3Y      Not assigned
# 262      M4Y  Downtown Toronto
# 263      M5Y      Not assigned
# 264      M6Y      Not assigned
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M9Y      Not assigned
# 275      M1Z      Not assigned
# 276      M2Z      Not assigned
# 277      M3Z      Not assigned
# 278      M4Z      Not assigned
# 279      M5Z      Not assigned
# 280      M6Z      Not assigned
# 281      M7Z      Not assigned
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 9                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 13                                        Not assigned
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 20                                        Not assigned
# 21                                        Not assigned
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# ..                                                 ...
# 258                                       Not assigned
# 259                                       Not assigned
# 260                                       Not assigned
# 261                                       Not assigned
# 262                               Church and Wellesley
# 263                                       Not assigned
# 264                                       Not assigned
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 274                                       Not assigned
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
# 287                                       Not assigned
#
# [288 rows x 3 columns]

# %%
df.describe()
# Out:
#        Postcode       Borough Neighbourhood
# count       288           288           288
# unique      180            12           209
# top         M8Y  Not assigned  Not assigned
# freq          8            77            78

# %%
#Filter to select rows that have Borough value != 'Not assigned'
filterDf = df[df.Borough != 'Not assigned']
filterDf
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# 38       M9C         Etobicoke
# ..       ...               ...
# 235      M9V         Etobicoke
# 236      M1W       Scarborough
# 239      M4W  Downtown Toronto
# 240      M5W  Downtown Toronto
# 243      M8W         Etobicoke
# 244      M8W         Etobicoke
# 245      M9W         Etobicoke
# 246      M1X       Scarborough
# 249      M4X  Downtown Toronto
# 250      M4X  Downtown Toronto
# 251      M5X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 255      M8X         Etobicoke
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 262      M4Y  Downtown Toronto
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38                                   Bloordale Gardens
# ..                                                 ...
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                                          Alderwood
# 244                                        Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                                        Cabbagetown
# 250                                     St. James Town
# 251                               First Canadian Place
# 252                                   Underground city
# 255                                       The Kingsway
# 256                                    Montgomery Road
# 257                                     Old Mill North
# 262                               Church and Wellesley
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
#
# [211 rows x 3 columns]

# %%
aggregateFunc = {'Postcode':'first', 'Borough':'first','Neighbourhood':lambda x: "%s " % ','.join(x)}
#groupDf = filterDf.groupby(['Postcode', 'Borough']).aggregate(aggregateFunc).reindex(columns=['Postcode', 'Borough', 'Neighbourhood'])
groupDf = filterDf.groupby(['Postcode', 'Borough']).aggregate(aggregateFunc).reindex(columns=['Postcode', 'Borough','Neighbourhood'])
groupDf['Latitude'] = ''
groupDf['Longitude'] = ''
groupDf
# Out:
#                           Postcode           Borough  \
# Postcode Borough
# M1B      Scarborough           M1B       Scarborough
# M1C      Scarborough           M1C       Scarborough
# M1E      Scarborough           M1E       Scarborough
# M1G      Scarborough           M1G       Scarborough
# M1H      Scarborough           M1H       Scarborough
# M1J      Scarborough           M1J       Scarborough
# M1K      Scarborough           M1K       Scarborough
# M1L      Scarborough           M1L       Scarborough
# M1M      Scarborough           M1M       Scarborough
# M1N      Scarborough           M1N       Scarborough
# M1P      Scarborough           M1P       Scarborough
# M1R      Scarborough           M1R       Scarborough
# M1S      Scarborough           M1S       Scarborough
# M1T      Scarborough           M1T       Scarborough
# M1V      Scarborough           M1V       Scarborough
# M1W      Scarborough           M1W       Scarborough
# M1X      Scarborough           M1X       Scarborough
# M2H      North York            M2H        North York
# M2J      North York            M2J        North York
# M2K      North York            M2K        North York
# M2L      North York            M2L        North York
# M2M      North York            M2M        North York
# M2N      North York            M2N        North York
# M2P      North York            M2P        North York
# M2R      North York            M2R        North York
# M3A      North York            M3A        North York
# M3B      North York            M3B        North York
# M3C      North York            M3C        North York
# M3H      North York            M3H        North York
# M3J      North York            M3J        North York
# ...                            ...               ...
# M6C      York                  M6C              York
# M6E      York                  M6E              York
# M6G      Downtown Toronto      M6G  Downtown Toronto
# M6H      West Toronto          M6H      West Toronto
# M6J      West Toronto          M6J      West Toronto
# M6K      West Toronto          M6K      West Toronto
# M6L      North York            M6L        North York
# M6M      York                  M6M              York
# M6N      York                  M6N              York
# M6P      West Toronto          M6P      West Toronto
# M6R      West Toronto          M6R      West Toronto
# M6S      West Toronto          M6S      West Toronto
# M7A      Queen's Park          M7A      Queen's Park
# M7R      Mississauga           M7R       Mississauga
# M7Y      East Toronto          M7Y      East Toronto
# M8V      Etobicoke             M8V         Etobicoke
# M8W      Etobicoke             M8W         Etobicoke
# M8X      Etobicoke             M8X         Etobicoke
# M8Y      Etobicoke             M8Y         Etobicoke
# M8Z      Etobicoke             M8Z         Etobicoke
# M9A      Etobicoke             M9A         Etobicoke
# M9B      Etobicoke             M9B         Etobicoke
# M9C      Etobicoke             M9C         Etobicoke
# M9L      North York            M9L        North York
# M9M      North York            M9M        North York
# M9N      York                  M9N              York
# M9P      Etobicoke             M9P         Etobicoke
# M9R      Etobicoke             M9R         Etobicoke
# M9V      Etobicoke             M9V         Etobicoke
# M9W      Etobicoke             M9W         Etobicoke
#
#                                                                Neighbourhood  \
# Postcode Borough
# M1B      Scarborough                                          Rouge,Malvern
# M1C      Scarborough                   Highland Creek,Rouge Hill,Port Union
# M1E      Scarborough                        Guildwood,Morningside,West Hill
# M1G      Scarborough                                                 Woburn
# M1H      Scarborough                                              Cedarbrae
# M1J      Scarborough                                    Scarborough Village
# M1K      Scarborough              East Birchmount Park,Ionview,Kennedy Park
# M1L      Scarborough                          Clairlea,Golden Mile,Oakridge
# M1M      Scarborough          Cliffcrest,Cliffside,Scarborough Village West
# M1N      Scarborough                             Birch Cliff,Cliffside West
# M1P      Scarborough       Dorset Park,Scarborough Town Centre,Wexford He...
# M1R      Scarborough                                       Maryvale,Wexford
# M1S      Scarborough                                              Agincourt
# M1T      Scarborough                  Clarks Corners,Sullivan,Tam O'Shanter
# M1V      Scarborough       Agincourt North,L'Amoreaux East,Milliken,Steel...
# M1W      Scarborough                                        L'Amoreaux West
# M1X      Scarborough                                            Upper Rouge
# M2H      North York                                       Hillcrest Village
# M2J      North York                              Fairview,Henry Farm,Oriole
# M2K      North York                                         Bayview Village
# M2L      North York                                 Silver Hills,York Mills
# M2M      North York                                  Newtonbrook,Willowdale
# M2N      North York                                        Willowdale South
# M2P      North York                                         York Mills West
# M2R      North York                                         Willowdale West
# M3A      North York                                               Parkwoods
# M3B      North York                                         Don Mills North
# M3C      North York                         Flemingdon Park,Don Mills South
# M3H      North York           Bathurst Manor,Downsview North,Wilson Heights
# M3J      North York                          Northwood Park,York University
# ...                                                                      ...
# M6C      York                                            Humewood-Cedarvale
# M6E      York                                           Caledonia-Fairbanks
# M6G      Downtown Toronto                                          Christie
# M6H      West Toronto                           Dovercourt Village,Dufferin
# M6J      West Toronto                               Little Portugal,Trinity
# M6K      West Toronto            Brockton,Exhibition Place,Parkdale Village
# M6L      North York                        Downsview,North Park,Upwood Park
# M6M      York                   Del Ray,Keelesdale,Mount Dennis,Silverthorn
# M6N      York                                  The Junction North,Runnymede
# M6P      West Toronto                          High Park,The Junction South
# M6R      West Toronto                                 Parkdale,Roncesvalles
# M6S      West Toronto                                     Runnymede,Swansea
# M7A      Queen's Park                                          Not assigned
# M7R      Mississauga                  Canada Post Gateway Processing Centre
# M7Y      East Toronto      Business Reply Mail Processing Centre 969 East...
# M8V      Etobicoke               Humber Bay Shores,Mimico South,New Toronto
# M8W      Etobicoke                                    Alderwood,Long Branch
# M8X      Etobicoke              The Kingsway,Montgomery Road,Old Mill North
# M8Y      Etobicoke         Humber Bay,King's Mill Park,Kingsway Park Sout...
# M8Z      Etobicoke         Kingsway Park South West,Mimico NW,The Queensw...
# M9A      Etobicoke                                         Islington Avenue
# M9B      Etobicoke         Cloverdale,Islington,Martin Grove,Princess Gar...
# M9C      Etobicoke         Bloordale Gardens,Eringate,Markland Wood,Old B...
# M9L      North York                                           Humber Summit
# M9M      North York                                         Emery,Humberlea
# M9N      York                                                        Weston
# M9P      Etobicoke                                                Westmount
# M9R      Etobicoke         Kingsview Village,Martin Grove Gardens,Richvie...
# M9V      Etobicoke         Albion Gardens,Beaumond Heights,Humbergate,Jam...
# M9W      Etobicoke                                                Northwest
#
#                           Latitude Longitude
# Postcode Borough
# M1B      Scarborough
# M1C      Scarborough
# M1E      Scarborough
# M1G      Scarborough
# M1H      Scarborough
# M1J      Scarborough
# M1K      Scarborough
# M1L      Scarborough
# M1M      Scarborough
# M1N      Scarborough
# M1P      Scarborough
# M1R      Scarborough
# M1S      Scarborough
# M1T      Scarborough
# M1V      Scarborough
# M1W      Scarborough
# M1X      Scarborough
# M2H      North York
# M2J      North York
# M2K      North York
# M2L      North York
# M2M      North York
# M2N      North York
# M2P      North York
# M2R      North York
# M3A      North York
# M3B      North York
# M3C      North York
# M3H      North York
# M3J      North York
# ...                            ...       ...
# M6C      York
# M6E      York
# M6G      Downtown Toronto
# M6H      West Toronto
# M6J      West Toronto
# M6K      West Toronto
# M6L      North York
# M6M      York
# M6N      York
# M6P      West Toronto
# M6R      West Toronto
# M6S      West Toronto
# M7A      Queen's Park
# M7R      Mississauga
# M7Y      East Toronto
# M8V      Etobicoke
# M8W      Etobicoke
# M8X      Etobicoke
# M8Y      Etobicoke
# M8Z      Etobicoke
# M9A      Etobicoke
# M9B      Etobicoke
# M9C      Etobicoke
# M9L      North York
# M9M      North York
# M9N      York
# M9P      Etobicoke
# M9R      Etobicoke
# M9V      Etobicoke
# M9W      Etobicoke
#
# [103 rows x 5 columns]

# %%
groupDf.shape
# Out:
# (103, 5)

# %%
coordDf = pd.read_csv("http://cocl.us/Geospatial_data")
coordDf.columns = ['Postcode', 'Latitude', 'Longitude']
coordDf.reindex(['Postcode'])
coordDf.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
# Function to search for coords based on Postcode
def searchCoords(Postcode):
    for idx, row in coordDf.iterrows():
        if(row['Postcode'] == Postcode):
            return row['Latitude'], row['Longitude']

# %%
for idx, row in groupDf.iterrows():
    lat, lng = searchCoords(row['Postcode'])
    row['Latitude'] = lat
    row['Longitude'] = lng
    # print(lat,lng)

groupDf
# Out:
#                           Postcode           Borough  \
# Postcode Borough
# M1B      Scarborough           M1B       Scarborough
# M1C      Scarborough           M1C       Scarborough
# M1E      Scarborough           M1E       Scarborough
# M1G      Scarborough           M1G       Scarborough
# M1H      Scarborough           M1H       Scarborough
# M1J      Scarborough           M1J       Scarborough
# M1K      Scarborough           M1K       Scarborough
# M1L      Scarborough           M1L       Scarborough
# M1M      Scarborough           M1M       Scarborough
# M1N      Scarborough           M1N       Scarborough
# M1P      Scarborough           M1P       Scarborough
# M1R      Scarborough           M1R       Scarborough
# M1S      Scarborough           M1S       Scarborough
# M1T      Scarborough           M1T       Scarborough
# M1V      Scarborough           M1V       Scarborough
# M1W      Scarborough           M1W       Scarborough
# M1X      Scarborough           M1X       Scarborough
# M2H      North York            M2H        North York
# M2J      North York            M2J        North York
# M2K      North York            M2K        North York
# M2L      North York            M2L        North York
# M2M      North York            M2M        North York
# M2N      North York            M2N        North York
# M2P      North York            M2P        North York
# M2R      North York            M2R        North York
# M3A      North York            M3A        North York
# M3B      North York            M3B        North York
# M3C      North York            M3C        North York
# M3H      North York            M3H        North York
# M3J      North York            M3J        North York
# ...                            ...               ...
# M6C      York                  M6C              York
# M6E      York                  M6E              York
# M6G      Downtown Toronto      M6G  Downtown Toronto
# M6H      West Toronto          M6H      West Toronto
# M6J      West Toronto          M6J      West Toronto
# M6K      West Toronto          M6K      West Toronto
# M6L      North York            M6L        North York
# M6M      York                  M6M              York
# M6N      York                  M6N              York
# M6P      West Toronto          M6P      West Toronto
# M6R      West Toronto          M6R      West Toronto
# M6S      West Toronto          M6S      West Toronto
# M7A      Queen's Park          M7A      Queen's Park
# M7R      Mississauga           M7R       Mississauga
# M7Y      East Toronto          M7Y      East Toronto
# M8V      Etobicoke             M8V         Etobicoke
# M8W      Etobicoke             M8W         Etobicoke
# M8X      Etobicoke             M8X         Etobicoke
# M8Y      Etobicoke             M8Y         Etobicoke
# M8Z      Etobicoke             M8Z         Etobicoke
# M9A      Etobicoke             M9A         Etobicoke
# M9B      Etobicoke             M9B         Etobicoke
# M9C      Etobicoke             M9C         Etobicoke
# M9L      North York            M9L        North York
# M9M      North York            M9M        North York
# M9N      York                  M9N              York
# M9P      Etobicoke             M9P         Etobicoke
# M9R      Etobicoke             M9R         Etobicoke
# M9V      Etobicoke             M9V         Etobicoke
# M9W      Etobicoke             M9W         Etobicoke
#
#                                                                Neighbourhood  \
# Postcode Borough
# M1B      Scarborough                                          Rouge,Malvern
# M1C      Scarborough                   Highland Creek,Rouge Hill,Port Union
# M1E      Scarborough                        Guildwood,Morningside,West Hill
# M1G      Scarborough                                                 Woburn
# M1H      Scarborough                                              Cedarbrae
# M1J      Scarborough                                    Scarborough Village
# M1K      Scarborough              East Birchmount Park,Ionview,Kennedy Park
# M1L      Scarborough                          Clairlea,Golden Mile,Oakridge
# M1M      Scarborough          Cliffcrest,Cliffside,Scarborough Village West
# M1N      Scarborough                             Birch Cliff,Cliffside West
# M1P      Scarborough       Dorset Park,Scarborough Town Centre,Wexford He...
# M1R      Scarborough                                       Maryvale,Wexford
# M1S      Scarborough                                              Agincourt
# M1T      Scarborough                  Clarks Corners,Sullivan,Tam O'Shanter
# M1V      Scarborough       Agincourt North,L'Amoreaux East,Milliken,Steel...
# M1W      Scarborough                                        L'Amoreaux West
# M1X      Scarborough                                            Upper Rouge
# M2H      North York                                       Hillcrest Village
# M2J      North York                              Fairview,Henry Farm,Oriole
# M2K      North York                                         Bayview Village
# M2L      North York                                 Silver Hills,York Mills
# M2M      North York                                  Newtonbrook,Willowdale
# M2N      North York                                        Willowdale South
# M2P      North York                                         York Mills West
# M2R      North York                                         Willowdale West
# M3A      North York                                               Parkwoods
# M3B      North York                                         Don Mills North
# M3C      North York                         Flemingdon Park,Don Mills South
# M3H      North York           Bathurst Manor,Downsview North,Wilson Heights
# M3J      North York                          Northwood Park,York University
# ...                                                                      ...
# M6C      York                                            Humewood-Cedarvale
# M6E      York                                           Caledonia-Fairbanks
# M6G      Downtown Toronto                                          Christie
# M6H      West Toronto                           Dovercourt Village,Dufferin
# M6J      West Toronto                               Little Portugal,Trinity
# M6K      West Toronto            Brockton,Exhibition Place,Parkdale Village
# M6L      North York                        Downsview,North Park,Upwood Park
# M6M      York                   Del Ray,Keelesdale,Mount Dennis,Silverthorn
# M6N      York                                  The Junction North,Runnymede
# M6P      West Toronto                          High Park,The Junction South
# M6R      West Toronto                                 Parkdale,Roncesvalles
# M6S      West Toronto                                     Runnymede,Swansea
# M7A      Queen's Park                                          Not assigned
# M7R      Mississauga                  Canada Post Gateway Processing Centre
# M7Y      East Toronto      Business Reply Mail Processing Centre 969 East...
# M8V      Etobicoke               Humber Bay Shores,Mimico South,New Toronto
# M8W      Etobicoke                                    Alderwood,Long Branch
# M8X      Etobicoke              The Kingsway,Montgomery Road,Old Mill North
# M8Y      Etobicoke         Humber Bay,King's Mill Park,Kingsway Park Sout...
# M8Z      Etobicoke         Kingsway Park South West,Mimico NW,The Queensw...
# M9A      Etobicoke                                         Islington Avenue
# M9B      Etobicoke         Cloverdale,Islington,Martin Grove,Princess Gar...
# M9C      Etobicoke         Bloordale Gardens,Eringate,Markland Wood,Old B...
# M9L      North York                                           Humber Summit
# M9M      North York                                         Emery,Humberlea
# M9N      York                                                        Weston
# M9P      Etobicoke                                                Westmount
# M9R      Etobicoke         Kingsview Village,Martin Grove Gardens,Richvie...
# M9V      Etobicoke         Albion Gardens,Beaumond Heights,Humbergate,Jam...
# M9W      Etobicoke                                                Northwest
#
#                           Latitude Longitude
# Postcode Borough
# M1B      Scarborough       43.8067  -79.1944
# M1C      Scarborough       43.7845  -79.1605
# M1E      Scarborough       43.7636  -79.1887
# M1G      Scarborough        43.771  -79.2169
# M1H      Scarborough       43.7731  -79.2395
# M1J      Scarborough       43.7447  -79.2395
# M1K      Scarborough       43.7279   -79.262
# M1L      Scarborough       43.7111  -79.2846
# M1M      Scarborough       43.7163  -79.2395
# M1N      Scarborough       43.6927  -79.2648
# M1P      Scarborough       43.7574  -79.2733
# M1R      Scarborough       43.7501  -79.2958
# M1S      Scarborough       43.7942   -79.262
# M1T      Scarborough       43.7816  -79.3043
# M1V      Scarborough       43.8153  -79.2846
# M1W      Scarborough       43.7995  -79.3184
# M1X      Scarborough       43.8361  -79.2056
# M2H      North York        43.8038  -79.3635
# M2J      North York        43.7785  -79.3466
# M2K      North York        43.7869   -79.386
# M2L      North York        43.7575  -79.3747
# M2M      North York        43.7891  -79.4085
# M2N      North York        43.7701  -79.4085
# M2P      North York        43.7528     -79.4
# M2R      North York        43.7827  -79.4423
# M3A      North York        43.7533  -79.3297
# M3B      North York        43.7459  -79.3522
# M3C      North York        43.7259  -79.3409
# M3H      North York        43.7543  -79.4423
# M3J      North York         43.768  -79.4873
# ...                            ...       ...
# M6C      York              43.6938  -79.4282
# M6E      York               43.689  -79.4535
# M6G      Downtown Toronto  43.6695  -79.4226
# M6H      West Toronto       43.669  -79.4423
# M6J      West Toronto      43.6479  -79.4197
# M6K      West Toronto      43.6368  -79.4282
# M6L      North York        43.7138  -79.4901
# M6M      York              43.6911   -79.476
# M6N      York              43.6732  -79.4873
# M6P      West Toronto      43.6616  -79.4648
# M6R      West Toronto       43.649  -79.4563
# M6S      West Toronto      43.6516  -79.4844
# M7A      Queen's Park      43.6623  -79.3895
# M7R      Mississauga        43.637  -79.6158
# M7Y      East Toronto      43.6627  -79.3216
# M8V      Etobicoke         43.6056  -79.5013
# M8W      Etobicoke         43.6024  -79.5435
# M8X      Etobicoke         43.6537  -79.5069
# M8Y      Etobicoke         43.6363  -79.4985
# M8Z      Etobicoke         43.6288   -79.521
# M9A      Etobicoke         43.6679  -79.5322
# M9B      Etobicoke         43.6509  -79.5547
# M9C      Etobicoke         43.6435  -79.5772
# M9L      North York        43.7563   -79.566
# M9M      North York        43.7248  -79.5322
# M9N      York              43.7069  -79.5182
# M9P      Etobicoke         43.6963  -79.5322
# M9R      Etobicoke         43.6889  -79.5547
# M9V      Etobicoke         43.7394  -79.5884
# M9W      Etobicoke         43.7067  -79.5941
#
# [103 rows x 5 columns]

# %%
groupDf.columns
# Out:
# Index(['Postcode', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude'], dtype='object')

# %%
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you get an error
import folium # map rendering library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.3 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          3.2.0-py36_0      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-0                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_1              --> 2019.6.16-py36_1     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          90 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.20.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
address = 'Toronto, Ontario'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
# Create map of toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(groupDf['Latitude'], groupDf['Longitude'], groupDf['Borough'], groupDf['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
